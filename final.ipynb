# %% [markdown]
# # Programming and Data Analysis
#
# > Final
#
# Kuo, Yao-Jen <yaojenkuo@ntu.edu.tw> from [DATAINPOINT](https://www.datainpoint.com)

# %%
import unittest
import requests
import numpy as np
import pandas as pd

# %% [markdown]
# ## Instructions
#
# - We've imported necessary modules at the top of each assignment.
# - We've defined the names of functions/inputs/parameters for you.
# - Save a copy in your own Google Drive before getting started.
#     - File -> Save a copy in Drive.
# - Write down your solution between the comments `### BEGIN SOLUTION` and `### END SOLUTION`.
# - It is NECESSARY to `return` the answer, tests will fail by just printing out the answer.
# - DON'Ts
#     - DON'T use `input()` function in your assignments.
#     - DON'T use Safari browser to export Colab as Python script.
#     - DON'T nest your solution in another `def` function code block.
#     - DON'T install packages using `!pip install <package_name>` since it is not a valid Python syntax(it is indeed a valid bash command though.)
# - Running tests to see if your solutions are right:
#     - File -> Save.
#     - Runtime -> Restart and run all.
# - When you are ready to submit, click File -> Download -> Download `.py`.
#
# ![](https://i.imgur.com/Y1BcDdx.png)
#
# - Open a new Colab in a private window, upload the script and run tests again before submission to make sure the script is executable in a fresh new Colab.
#
# ![](https://i.imgur.com/ojlvbds.png)
#
# - Upload to the Assignment session on NTU COOL.

# %% [markdown]
# ## In the following exercises, you will need some files to complete the functions. Run the cell below to download those files at your working directory.

# %%
import requests

file_names = ["taiwan_election_2022.csv"]
for file_name in file_names:
    file_url = f"https://raw.githubusercontent.com/datainpoint/asgmts-programming-and-data-analysis-ntu-2022/main/{file_name}"
    r = requests.get(file_url)
    with open(file_name , "wb") as f:
        f.write(r.content)

# %% [markdown]
# ## 01. Define a function named `import_taiwan_election_2022_csv()` which imports `taiwan_election_2022.csv` in working directory as a `DataFrame`.

# %%
def import_taiwan_election_2022_csv() -> pd.core.frame.DataFrame:
    """
    >>> taiwan_election_2022_csv = import_taiwan_election_2022_csv()
    >>> type(taiwan_election_2022_csv)
    pandas.core.frame.DataFrame
    >>> taiwan_election_2022_csv.shape
    (408641, 10)
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 02. Define a function named `sum_total_votes_by_campaign()` which returns the total votes of each campaign.

# %%
def sum_total_votes_by_campaign() -> pd.core.series.Series:
    """
    >>> total_votes_by_campaign = sum_total_votes_by_campaign()
    >>> type(total_votes_by_campaign)
    pandas.core.series.Series
    >>> total_votes_by_campaign
    campaign
    縣市議員    11408183
    縣市長     11397162
    Name: votes, dtype: int64
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 03. Define a function named `find_column_distincts()` which returns distinct values given column names of `taiwan_election_2022.csv`.

# %%
def find_column_distincts(x: str) -> np.ndarray:
    """
    >>> find_column_distincts("county")
    array(['苗栗縣', '桃園市', '高雄市', '臺南市', '嘉義縣', '花蓮縣', '金門縣', '新竹縣', '澎湖縣',
           '臺北市', '臺東縣', '臺中市', '新北市', '屏東縣', '連江縣', '新竹市', '宜蘭縣', '南投縣',
           '雲林縣', '嘉義市', '彰化縣', '基隆市'], dtype=object)
    >>> find_column_distincts("party")
    array(['無', '中國國民黨', '民主進步黨', '時代力量', '台灣基進', '台灣民眾黨', '小民參政歐巴桑聯盟', '新黨',
           '綠黨', '親民黨', '台灣維新', '無黨團結聯盟', '左翼聯盟', '台灣團結聯盟', '龍黨', '共和黨',
           '金色力量黨', '中國國家社會主義勞工黨', '台灣動物保護黨', '社會民主黨', '臺灣人民共產黨', '前進黨',
           '勞動黨', '天一黨', '台灣新住民黨', '中華統一促進黨', '台灣君民黨', '台澎黨', '正神名黨',
           '中國和平統一黨'], dtype=object)
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 04. Define a function named `sum_votes_by_campaign_and_party()` which returns the total votes of each campaign and party.

# %%
def sum_votes_by_campaign_and_party(x: str) -> pd.core.frame.DataFrame:
    """
    >>> sum_votes_by_campaign_and_party("councillor")
       campaign        party    votes
    0      縣市議員        中國國民黨  4306343
    1      縣市議員        民主進步黨  3796575
    2      縣市議員            無  2246798
    3      縣市議員        台灣民眾黨   456627
    4      縣市議員         時代力量   177666
    5      縣市議員         台灣基進   124070
    6      縣市議員       無黨團結聯盟   108924
    7      縣市議員    小民參政歐巴桑聯盟    40704
    8      縣市議員       台灣團結聯盟    38193
    9      縣市議員           新黨    34422
    10     縣市議員        社會民主黨    28417
    11     縣市議員           綠黨    13901
    12     縣市議員          親民黨    11875
    13     縣市議員          勞動黨     7308
    14     縣市議員      台灣動物保護黨     4480
    15     縣市議員         正神名黨     3691
    16     縣市議員         台灣維新     2845
    17     縣市議員         左翼聯盟     1498
    18     縣市議員      中華統一促進黨     1160
    19     縣市議員        金色力量黨      816
    20     縣市議員        台灣君民黨      563
    21     縣市議員       台灣新住民黨      529
    22     縣市議員          前進黨      265
    23     縣市議員      中國和平統一黨      182
    24     縣市議員      臺灣人民共產黨      165
    25     縣市議員  中國國家社會主義勞工黨       99
    26     縣市議員          共和黨       67
    >>> sum_votes_by_campaign_and_party("mayor")
       campaign    party    votes
    0       縣市長    中國國民黨  5701977
    1       縣市長    民主進步黨  4743468
    2       縣市長        無   705872
    3       縣市長    台灣民眾黨   169459
    4       縣市長     時代力量    70503
    5       縣市長  台灣動物保護黨     2367
    6       縣市長     台灣維新     1851
    7       縣市長      天一黨      919
    8       縣市長      共和黨      316
    9       縣市長      台澎黨      256
    10      縣市長       龍黨      174
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 05. Define a function named `calculate_votes_percentage_by_campaign_and_party()` which returns the votes percentage of each campaign and party, showing the top 5 parties respectively.

# %%
def calculate_votes_percentage_by_campaign_and_party(x: str) -> pd.core.frame.DataFrame:
    """
    >>> calculate_votes_percentage_by_campaign_and_party("councillor")
           campaign        party    votes percentage
    0      縣市議員        中國國民黨  4306343      38.0%
    1      縣市議員        民主進步黨  3796575      33.0%
    2      縣市議員            無  2246798      20.0%
    3      縣市議員        台灣民眾黨   456627       4.0%
    4      縣市議員         時代力量   177666       2.0%
    >>> calculate_votes_percentage_by_campaign_and_party("mayor")
       campaign    party    votes percentage
    0       縣市長    中國國民黨  5701977      50.0%
    1       縣市長    民主進步黨  4743468      42.0%
    2       縣市長        無   705872       6.0%
    3       縣市長    台灣民眾黨   169459       1.0%
    4       縣市長     時代力量    70503       1.0%
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 06. Define a function named `sum_votes_by_county_type_and_party()` which returns the total votes of each county type and party.
#
# ```python
# county_type = {
#     "六都": ["桃園市", "高雄市", "臺南市", "臺北市", "臺中市", "新北市"],
#     "非六都": ["苗栗縣", "嘉義縣", "花蓮縣", "金門縣", "新竹縣", "澎湖縣", "臺東縣", "屏東縣", "連江縣", "新竹市", "宜蘭縣", "南投縣", "雲林縣", "嘉義市", "彰化縣", "基隆市"]
# }
# ```

# %%
def sum_votes_by_county_type_and_party() -> pd.core.frame.DataFrame:
    """
    >>> sum_votes_by_county_type_and_party()
       county_type        party    votes
    0           六都        中國國民黨  7125755
    1           六都        民主進步黨  6120699
    2           六都            無  1451332
    3           六都        台灣民眾黨   398692
    4           六都         時代力量   121774
    5           六都         台灣基進   115013
    6           六都       無黨團結聯盟   107228
    7           六都    小民參政歐巴桑聯盟    40459
    8           六都           新黨    34422
    9           六都        社會民主黨    28417
    10          六都       台灣團結聯盟    20676
    11          六都      台灣動物保護黨     6847
    12          六都           綠黨     5908
    13          六都         台灣維新     4046
    14          六都          勞動黨     2035
    15          六都         左翼聯盟     1498
    16          六都        金色力量黨      816
    17          六都          共和黨      383
    18          六都          前進黨      265
    19          六都          台澎黨      256
    20          六都          親民黨      184
    21          六都      中國和平統一黨      182
    22          六都      臺灣人民共產黨      165
    23          六都  中國國家社會主義勞工黨       99
    24         非六都        中國國民黨  2882565
    25         非六都        民主進步黨  2419344
    26         非六都            無  1501338
    27         非六都        台灣民眾黨   227394
    28         非六都         時代力量   126395
    29         非六都       台灣團結聯盟    17517
    30         非六都          親民黨    11691
    31         非六都         台灣基進     9057
    32         非六都           綠黨     7993
    33         非六都          勞動黨     5273
    34         非六都         正神名黨     3691
    35         非六都       無黨團結聯盟     1696
    36         非六都      中華統一促進黨     1160
    37         非六都          天一黨      919
    38         非六都         台灣維新      650
    39         非六都        台灣君民黨      563
    40         非六都       台灣新住民黨      529
    41         非六都    小民參政歐巴桑聯盟      245
    42         非六都           龍黨      174
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 07. Define a function named `calculate_votes_percentage_by_county_type_and_party()` which returns the votes percentage of each county type and party, showing the top 5 parties respectively.

# %%
def calculate_votes_percentage_by_county_type_and_party() -> pd.core.frame.DataFrame:
    """
    >>> calculate_votes_percentage_by_county_type_and_party()
      county_type  party    votes percentage
    0          六都  中國國民黨  7125755      46.0%
    1          六都  民主進步黨  6120699      39.0%
    2          六都      無  1451332       9.0%
    3          六都  台灣民眾黨   398692       3.0%
    4          六都   時代力量   121774       1.0%
    5         非六都  中國國民黨  2882565      40.0%
    6         非六都  民主進步黨  2419344      34.0%
    7         非六都      無  1501338      21.0%
    8         非六都  台灣民眾黨   227394       3.0%
    9         非六都   時代力量   126395       2.0%
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 08. Define a function named `summarize_result_by_county_campaign()` which returns the election result given parameters `county` and `campaign`.

# %%
def summarize_result_by_county_campaign(county: str, campaign: str) -> pd.core.frame.DataFrame:
    """
    >>> summarize_result_by_county_campaign(county="臺北市", campaign="縣市長")
       county    party candidate   votes
    0     臺北市    中國國民黨       蔣萬安  575590
    1     臺北市    民主進步黨       陳時中  434558
    2     臺北市        無       黃珊珊  342141
    3     臺北市        無       童文薰    2425
    4     臺北市  台灣動物保護黨       張家豪    2367
    5     臺北市     台灣維新       蘇煥智    1851
    6     臺北市        無       王文娟     451
    7     臺北市        無       鄭匡宇     386
    8     臺北市        無       施奉先     383
    9     臺北市      共和黨       唐新民     316
    10    臺北市      台澎黨       黃聖峰     256
    11    臺北市        無       謝立康     227
    >>> summarize_result_by_county_campaign(county="臺北市", campaign="縣市議員")
        county        party       candidate  votes
    0      臺北市        中國國民黨             李彥秀  37669
    1      臺北市        中國國民黨             李柏毅  30325
    2      臺北市        民主進步黨             王世堅  29796
    3      臺北市        台灣民眾黨             黃瀞瑩  29270
    4      臺北市        社會民主黨             苗博雅  28417
    ..     ...          ...             ...    ...
    112    臺北市            無  高為人Sayun Watan    149
    113    臺北市            無             呂增塔    106
    114    臺北市  中國國家社會主義勞工黨              項豪     99
    115    臺北市            無             陳樹霖     71
    116    臺北市          共和黨             鄭穎隆     67

    [117 rows x 4 columns]
    >>> summarize_result_by_county_campaign(county="新北市", campaign="縣市長")
      county  party candidate    votes
    0    新北市  中國國民黨       侯友宜  1152555
    1    新北市  民主進步黨       林佳龍   693976
    >>> summarize_result_by_county_campaign(county="新北市", campaign="縣市議員")
        county    party candidate  votes
    0      新北市    中國國民黨       黃心華  32806
    1      新北市    中國國民黨       廖先翔  32190
    2      新北市    民主進步黨       陳乃瑜  31473
    3      新北市    中國國民黨       連斐璠  31408
    4      新北市    中國國民黨       林金結  29933
    ..     ...      ...       ...    ...
    121    新北市        無       郭柏成    436
    122    新北市        無       邱吉均    411
    123    新北市        無       簡元泰    346
    124    新北市  中國和平統一黨       陳玉鳳    182
    125    新北市       新黨       林霈宸     58

    [126 rows x 4 columns]
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 09. Define a function named `summarize_mayor_result_by_county()` which returns the election result of county mayors given `county`.

# %%
def summarize_mayor_result_by_county(county: str) -> pd.core.frame.DataFrame:
    """
    >>> summarize_mayor_result_by_county("臺北市")
       county    party candidate   votes percentage
    0     臺北市    中國國民黨       蔣萬安  575590      42.0%
    1     臺北市    民主進步黨       陳時中  434558      32.0%
    2     臺北市        無       黃珊珊  342141      25.0%
    3     臺北市        無       童文薰    2425       0.0%
    4     臺北市  台灣動物保護黨       張家豪    2367       0.0%
    5     臺北市     台灣維新       蘇煥智    1851       0.0%
    6     臺北市        無       王文娟     451       0.0%
    7     臺北市        無       鄭匡宇     386       0.0%
    8     臺北市        無       施奉先     383       0.0%
    9     臺北市      共和黨       唐新民     316       0.0%
    10    臺北市      台澎黨       黃聖峰     256       0.0%
    11    臺北市        無       謝立康     227       0.0%
    >>> summarize_mayor_result_by_county("新北市")
      county  party candidate    votes percentage
    0    新北市  中國國民黨       侯友宜  1152555      62.0%
    1    新北市  民主進步黨       林佳龍   693976      38.0%
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## 10. Define a function named `summarize_mayor_winners()` which returns the election winners of county mayor.

# %%
def summarize_mayor_winners() -> pd.core.frame.DataFrame:
    """
    >>> summarize_mayor_winners()
       county  party candidate    votes percentage
    0     花蓮縣  中國國民黨       徐榛蔚    96645      65.0%
    1     新竹縣  中國國民黨       楊文科   163662      63.0%
    2     新北市  中國國民黨       侯友宜  1152555      62.0%
    3     臺東縣  中國國民黨       饒慶鈴    68661      61.0%
    4     臺中市  中國國民黨       盧秀燕   799107      59.0%
    5     彰化縣  中國國民黨       王惠美   369133      57.0%
    6     雲林縣  中國國民黨       張麗善   207519      57.0%
    7     南投縣  中國國民黨       許淑華   154256      56.0%
    8     基隆市  中國國民黨       謝國樑    96784      53.0%
    9     桃園市  中國國民黨       張善政   557572      52.0%
    10    宜蘭縣  中國國民黨       林姿妙   119421      51.0%
    11    連江縣  中國國民黨       王忠銘     4337      51.0%
    12    臺北市  中國國民黨       蔣萬安   575590      42.0%
    13    新竹市  台灣民眾黨       高虹安    98121      45.0%
    14    嘉義縣  民主進步黨       翁章梁   171777      63.0%
    15    高雄市  民主進步黨       陳其邁   766147      58.0%
    16    臺南市  民主進步黨       黃偉哲   433684      49.0%
    17    屏東縣  民主進步黨       周春米   217537      49.0%
    18    澎湖縣  民主進步黨       陳光復    18777      37.0%
    19    金門縣      無       陳福海    23248      49.0%
    20    苗栗縣      無       鍾東錦   124603      43.0%
    """
    ### BEGIN SOLUTION
    
    ### END SOLUTION

# %% [markdown]
# ## Running tests
#
# Assignment session is finished, click Runtime -> Restart and run all to run the following tests.

# %%
class TestFinal(unittest.TestCase):
    def test_01_import_taiwan_election_2022_csv(self):
        taiwan_election_2022_csv = import_taiwan_election_2022_csv()
        self.assertIsInstance(taiwan_election_2022_csv, pd.core.frame.DataFrame)
        self.assertEqual(taiwan_election_2022_csv.shape, (408641, 10))
    def test_02_sum_total_votes_by_campaign(self):
        total_votes_by_campaign = sum_total_votes_by_campaign()
        self.assertIsInstance(total_votes_by_campaign, pd.core.series.Series)
        self.assertIn("縣市議員", total_votes_by_campaign.index)
        self.assertIn("縣市長", total_votes_by_campaign.index)
    def test_03_find_column_distincts(self):
        ans = find_column_distincts("county")
        self.assertEqual(ans.size, 22)
        self.assertIn("臺北市", ans)
        self.assertIn("嘉義縣", ans)
        self.assertIn("屏東縣", ans)
        ans = find_column_distincts("party")
        self.assertIn("民主進步黨", ans)
        self.assertIn("台灣基進", ans)
        self.assertIn("小民參政歐巴桑聯盟", ans)
    def test_04_sum_votes_by_campaign_and_party(self):
        votes_by_campaign_and_party = sum_votes_by_campaign_and_party("councillor")
        self.assertIsInstance(votes_by_campaign_and_party, pd.core.frame.DataFrame)
        self.assertEqual(votes_by_campaign_and_party.shape, (27, 3))
        votes_by_campaign_and_party = sum_votes_by_campaign_and_party("mayor")
        self.assertIsInstance(votes_by_campaign_and_party, pd.core.frame.DataFrame)
        self.assertEqual(votes_by_campaign_and_party.shape, (11, 3))
    def test_05_calculate_votes_percentage_by_campaign_and_party(self):
        votes_percentage_by_campaign_and_party = calculate_votes_percentage_by_campaign_and_party("councillor")
        self.assertIsInstance(votes_percentage_by_campaign_and_party, pd.core.frame.DataFrame)
        self.assertEqual(votes_percentage_by_campaign_and_party.shape, (5, 4))
        self.assertEqual(votes_percentage_by_campaign_and_party["party"].nunique(), 5)
        self.assertEqual(votes_percentage_by_campaign_and_party["percentage"].str.contains("%").sum(), 5)
        votes_percentage_by_campaign_and_party = calculate_votes_percentage_by_campaign_and_party("mayor")
        self.assertIsInstance(votes_percentage_by_campaign_and_party, pd.core.frame.DataFrame)
        self.assertEqual(votes_percentage_by_campaign_and_party.shape, (5, 4))
        self.assertEqual(votes_percentage_by_campaign_and_party["party"].nunique(), 5)
        self.assertEqual(votes_percentage_by_campaign_and_party["percentage"].str.contains("%").sum(), 5)
    def test_06_sum_votes_by_county_type_and_party(self):
        ans = sum_votes_by_county_type_and_party()
        self.assertIsInstance(ans, pd.core.frame.DataFrame)
        self.assertEqual(ans.shape, (43, 3))
        self.assertEqual(ans["county_type"].nunique(), 2)
        self.assertIn("民主進步黨", ans["party"].values)
        self.assertIn("台灣基進", ans["party"].values)
        self.assertIn("小民參政歐巴桑聯盟", ans["party"].values)
    def test_07_calculate_votes_percentage_by_county_type_and_party(self):
        ans = calculate_votes_percentage_by_county_type_and_party()
        self.assertIsInstance(ans, pd.core.frame.DataFrame)
        self.assertEqual(ans.shape, (10, 4))
        self.assertEqual(ans["county_type"].nunique(), 2)
        self.assertIn("民主進步黨", ans["party"].values)
        self.assertIn("台灣民眾黨", ans["party"].values)
        self.assertIn("時代力量", ans["party"].values)
    def test_08_summarize_result_by_county_campaign(self):
        ans = summarize_result_by_county_campaign(county="臺北市", campaign="縣市長")
        self.assertIsInstance(ans, pd.core.frame.DataFrame)
        self.assertEqual(ans.shape, (12, 4))
        self.assertEqual(ans["county"].nunique(), 1)
        ans = summarize_result_by_county_campaign(county="臺北市", campaign="縣市議員")
        self.assertIsInstance(ans, pd.core.frame.DataFrame)
        self.assertEqual(ans["county"].nunique(), 1)
        ans = summarize_result_by_county_campaign(county="新北市", campaign="縣市長")
        self.assertIsInstance(ans, pd.core.frame.DataFrame)
        self.assertEqual(ans.shape, (2, 4))
        self.assertEqual(ans["county"].nunique(), 1)
        ans = summarize_result_by_county_campaign(county="新北市", campaign="縣市議員")
        self.assertIsInstance(ans, pd.core.frame.DataFrame)
        self.assertEqual(ans["county"].nunique(), 1)
    def test_09_summarize_mayor_result_by_county(self):
        ans = summarize_mayor_result_by_county("臺北市")
        self.assertEqual(ans.shape, (12, 5))
        self.assertEqual(ans["county"].nunique(), 1)
        self.assertEqual(ans["percentage"].str.contains("%").sum(), 12)
        ans = summarize_mayor_result_by_county("新北市")
        self.assertEqual(ans.shape, (2, 5))
        self.assertEqual(ans["county"].nunique(), 1)
        self.assertEqual(ans["percentage"].str.contains("%").sum(), 2)
    def test_10_summarize_mayor_winners(self):
        ans = summarize_mayor_winners()
        self.assertIsInstance(ans, pd.core.frame.DataFrame)
        self.assertEqual(ans.shape, (21, 5))
        self.assertEqual(ans["county"].nunique(), 21)
        self.assertIn("中國國民黨", ans["party"].values)
        self.assertIn("台灣民眾黨", ans["party"].values)
        self.assertIn("無", ans["party"].values)
        self.assertIn("民主進步黨", ans["party"].values)
        self.assertEqual(ans["percentage"].str.contains("%").sum(), 21)

suite = unittest.TestLoader().loadTestsFromTestCase(TestFinal)
runner = unittest.TextTestRunner(verbosity=2)
test_results = runner.run(suite)
number_of_failures = len(test_results.failures)
number_of_errors = len(test_results.errors)
number_of_test_runs = test_results.testsRun
number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)

# %%
print("You've got {} successes among {} questions.".format(number_of_successes, number_of_test_runs))
print("You will get {} points in the exam.".format(number_of_successes * 2))
